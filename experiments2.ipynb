# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])  # You can specify the languages you want to use, e.g., ['en', 'fr']

# Read an image using OpenCV
image_path = r'C:\Users\abdullah\projects\Computer_Vision\Licence-Plate-Detection-Recognition\Vehicle-LicensePlate-2\train\images\21603940_jpg.rf.a2619f9fee54b787bd8402dbec2c1817.jpg'  # Replace with your image path
image = cv2.imread(image_path)

# Perform OCR on the image
results = reader.readtext(image_path)

import string

def remove_punctuations_and_whitespace(text):
    # Create a translation table to remove punctuation
    translator = str.maketrans('', '', string.punctuation)
    # Remove punctuation
    text = text.translate(translator)
    # Remove whitespace
    text = text.replace(' ', '').upper()
    return text

for (bbox, text, prob) in results:
    text = remove_punctuations_and_whitespace(text)
    print(f"Detected text: {text} (Confidence: {prob:.2f})")

# # Display the results
# for (bbox, text, prob) in results:
#     print(f"Detected text: {text} (Confidence: {prob:.2f})")
#     # Draw bounding box on the image
#     (top_left, top_right, bottom_right, bottom_left) = bbox
#     top_left = (int(top_left[0]), int(top_left[1]))
#     bottom_right = (int(bottom_right[0]), int(bottom_right[1]))
#     image = cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)
#     # Put detected text on the image
#     #image = cv2.putText(image, text, (top_left[0], top_left[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the image with detected text and bounding boxes
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Detected text: B2542KOZ (Confidence: 0.33)

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])  # You can specify the languages you want to use, e.g., ['en', 'fr']

# Read an image using OpenCV
image_path = r'C:\Users\abdullah\projects\Computer_Vision\Licence-Plate-Detection-Recognition\video\License_images\image_34.jpg'  # Replace with your image path
image = cv2.imread(image_path)

# Perform OCR on the image
results = reader.readtext(image_path)

import string

def remove_punctuations_and_whitespace(text):
    # Create a translation table to remove punctuation
    translator = str.maketrans('', '', string.punctuation)
    # Remove punctuation
    text = text.translate(translator)
    # Remove whitespace
    text = text.replace(' ', '').upper()
    return text

for (bbox, text, prob) in results:
    text = remove_punctuations_and_whitespace(text)
    print(f"Detected text: {text} (Confidence: {prob:.2f})")

# # Display the results
# for (bbox, text, prob) in results:
#     print(f"Detected text: {text} (Confidence: {prob:.2f})")
#     # Draw bounding box on the image
#     (top_left, top_right, bottom_right, bottom_left) = bbox
#     top_left = (int(top_left[0]), int(top_left[1]))
#     bottom_right = (int(bottom_right[0]), int(bottom_right[1]))
#     image = cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)
#     # Put detected text on the image
#     #image = cv2.putText(image, text, (top_left[0], top_left[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the image with detected text and bounding boxes
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
# Out:
# Detected text: THPKM (Confidence: 0.13)

# %%
from paddleocr import PaddleOCR,draw_ocr
# Paddleocr supports Chinese, English, French, German, Korean and Japanese.
# You can set the parameter `lang` as `ch`, `en`, `fr`, `german`, `korean`, `japan`
# to switch the language model in order.
ocr = PaddleOCR(use_angle_cls=True, lang='en') # need to run only once to download and load model into memory
img_path = r'C:\Users\abdullah\projects\Computer_Vision\Licence-Plate-Detection-Recognition\video\License_images\image_34.jpg'
result = ocr.ocr(img_path, cls=True)
for idx in range(len(result)):
    res = result[idx]
    for line in res:
        print(line)


# draw result
from PIL import Image
result = result[0]
image = Image.open(img_path).convert('RGB')
boxes = [line[0] for line in result]
txts = [line[1][0] for line in result]
scores = [line[1][1] for line in result]
im_show = draw_ocr(image, boxes, txts, scores, font_path='./fonts/simfang.ttf')
im_show = Image.fromarray(im_show)
im_show.save('result.jpg')
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/english/en_PP-OCRv3_det_infer.tar to C:\Users\abdullah/.paddleocr/whl\det\en\en_PP-OCRv3_det_infer\en_PP-OCRv3_det_infer.tar
# 100%|██████████| 4.00M/4.00M [00:21<00:00, 190kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_infer.tar to C:\Users\abdullah/.paddleocr/whl\rec\en\en_PP-OCRv4_rec_infer\en_PP-OCRv4_rec_infer.tar
# 100%|██████████| 10.2M/10.2M [00:13<00:00, 751kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to C:\Users\abdullah/.paddleocr/whl\cls\ch_ppocr_mobile_v2.0_cls_infer\ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:20<00:00, 108kiB/s]
# ...
